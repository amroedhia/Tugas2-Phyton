# %%
import pandas as pd

# %%
df = pd.read_csv('https://query.data.world/s/w2gutjuuavlf5roy4ulifc4jv425jt')

# %%
df.head()
# Out:
#    year  Northeast   West  Midwest  South
# 0  1999       65.3  194.4     89.5  150.1
# 1  2000       66.4  184.7     90.0  142.2
# 2  2001       66.4  180.2     87.5  133.1
# 3  2002       64.9  176.9     85.5  132.3
# 4  2003       63.6  172.6     82.6  127.7

# %%
df.tail()
# Out:
#     year  Northeast        West    Midwest       South
# 13  2012  56.500000  130.000000  75.300000  113.700000
# 14  2013  58.556207  125.514101  74.206995  107.800798
# 15  2014  59.210216  129.417170  75.826762  108.735377
# 16  2015  58.161918  124.075181  73.983297  115.819414
# 17  2016  59.907755  122.319777  74.298836  113.623508

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
# year         18 non-null int64
# Northeast    18 non-null float64
# West         18 non-null float64
# Midwest      18 non-null float64
# South        18 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 848.0 bytes

# %%
df.describe()
# Out:
#               year  Northeast        West    Midwest       South
# count    18.000000  18.000000   18.000000  18.000000   18.000000
# mean   2007.500000  60.618672  152.007013  79.517549  122.776617
# std       5.338539   3.630555   24.008035   5.498284   11.951412
# min    1999.000000  56.500000  122.319777  73.983297  107.800798
# 25%    2003.250000  57.740479  130.950000  75.300000  113.700000
# 50%    2007.500000  59.455108  147.350000  77.750000  118.250000
# 75%    2011.750000  64.350000  173.050000  82.550000  131.850000
# max    2016.000000  66.400000  194.400000  90.000000  150.100000

# %%
df.groupby('year').mean()
# Out:
#       Northeast        West    Midwest       South
# year
# 1999  65.300000  194.400000  89.500000  150.100000
# 2000  66.400000  184.700000  90.000000  142.200000
# 2001  66.400000  180.200000  87.500000  133.100000
# 2002  64.900000  176.900000  85.500000  132.300000
# 2003  63.600000  172.600000  82.600000  127.700000
# 2004  64.600000  173.200000  82.400000  132.800000
# 2005  61.700000  166.200000  80.400000  130.500000
# 2006  59.700000  158.800000  79.300000  119.800000
# 2007  58.700000  152.900000  77.900000  123.600000
# 2008  56.800000  141.800000  77.600000  116.700000
# 2009  56.500000  133.800000  75.600000  113.700000
# 2010  57.600000  135.000000  74.100000  114.300000
# 2011  56.600000  134.300000  75.300000  113.500000
# 2012  56.500000  130.000000  75.300000  113.700000
# 2013  58.556207  125.514101  74.206995  107.800798
# 2014  59.210216  129.417170  75.826762  108.735377
# 2015  58.161918  124.075181  73.983297  115.819414
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
plt.plot(df['Northeast'], label='Northeast')
plt.plot(df['West'], label='West')
plt.plot(df['Midwest'], label='Midwest')
plt.plot(df['South'], label='South')
plt.xlabel('Year')
plt.ylabel('Numbers')
plt.title('Census Region : Marriage States Rate')
plt.legend()
plt.show()
